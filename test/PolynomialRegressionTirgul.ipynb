# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot  as plt
warnings.filterwarnings("ignore")

# %%
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
print(f"x:{X.ndim}")
print(f"y:{y.ndim}")
# Out:
# x:2
# y:2

# %%
plt.scatter(X,y, norm=True , marker=6)
